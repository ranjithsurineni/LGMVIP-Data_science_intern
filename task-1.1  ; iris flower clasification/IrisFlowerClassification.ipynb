# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
iris_flower = pd.read_csv('iris.csv')
iris_flower.index = [i for i in range(1,151)] 
iris_flower
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1      1            5.1           3.5            1.4           0.2
# 2      2            4.9           3.0            1.4           0.2
# 3      3            4.7           3.2            1.3           0.2
# 4      4            4.6           3.1            1.5           0.2
# 5      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 146  146            6.7           3.0            5.2           2.3
# 147  147            6.3           2.5            5.0           1.9
# 148  148            6.5           3.0            5.2           2.0
# 149  149            6.2           3.4            5.4           2.3
# 150  150            5.9           3.0            5.1           1.8
#
#             Species
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# ..              ...
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
# 150  Iris-virginica
#
# [150 rows x 6 columns]

# %%
iris_flower.shape
# Out:
# (150, 6)

# %%
iris_flower.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris_flower.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 8.2+ KB

# %%
iris_flower.isna().any()
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
iris_flower.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris_flower.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris_flower['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris_flower['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
colors = []
for index in iris_flower['Species'].unique():
    if index=='Iris-setosa':
        colors.append("purple")
    elif index=='Iris-versicolor':
        colors.append("violet")
    else:
        colors.append("black")
print(colors)
# Out:
# ['purple', 'violet', 'black']

# %%
iris_flower['Species'].value_counts().plot(kind="bar",color=colors,xlabel="Species",ylabel="Total no. of Species")
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Total no. of Species'>

# %%
sns.countplot(data=iris_flower)
plt.show()

# %%
sns.heatmap(iris_flower.corr(),linewidth=4,annot=True,cmap=sns.cubehelix_palette(as_cmap=True))
plt.title("Correlation",size=18)
plt.show()

# %%
iris_flower.hist()
plt.show()

# %%
iris_flower.plot(kind ='density',subplots = True, layout =(3,3),sharex = False)
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %%
iris_flower.plot(kind ='box',subplots = True, layout =(2,5),sharex = False)
# Out:
# Id                  AxesSubplot(0.125,0.53;0.133621x0.35)
# SepalLengthCm    AxesSubplot(0.285345,0.53;0.133621x0.35)
# SepalWidthCm      AxesSubplot(0.44569,0.53;0.133621x0.35)
# PetalLengthCm    AxesSubplot(0.606034,0.53;0.133621x0.35)
# PetalWidthCm     AxesSubplot(0.766379,0.53;0.133621x0.35)
# Species             AxesSubplot(0.125,0.11;0.133621x0.35)
# dtype: object

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='PetalLengthCm',data=iris_flower)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='PetalWidthCm',data=iris_flower)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='SepalLengthCm',data=iris_flower)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='SepalWidthCm',data=iris_flower)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.pairplot(iris_flower,hue='Species');

# %%
from sklearn.preprocessing import LabelEncoder

iris_flower['Species'] = LabelEncoder().fit_transform(iris_flower['Species'])

# %%
iris_flower['Species'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

Xtrain, Xtest, Ytrain, Ytest = train_test_split(iris_flower.loc[:,'SepalLengthCm':'PetalWidthCm'],iris_flower.loc[:,'Species'],train_size=80,test_size=20)

# %%
Xtrain.sort_index().shape
# Out:
# (80, 4)

# %%
Xtest.sort_index().shape
# Out:
# (20, 4)

# %%
Ytrain.sort_index().shape
# Out:
# (80,)

# %%
Ytest.sort_index().shape
# Out:
# (20,)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
Xtrain = sc.fit_transform(Xtrain)
Xtest = sc.transform(Xtest)

# %% [markdown]
# # Model Selection

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.linear_model import LogisticRegression

# %%
logReg= LogisticRegression()
logReg.fit(Xtrain, Ytrain)
# Out:
# LogisticRegression()

# %%
log_prediction=logReg.predict(Xtest)
log_prediction
# Out:
# array([2, 0, 0, 2, 2, 0, 1, 1, 0, 2, 1, 2, 1, 0, 0, 2, 2, 1, 0, 1],
#       dtype=int64)

# %%
print("Logistic Model Accuracy:")
accuracy_score(Ytest, log_prediction)
# Out:
# Logistic Model Accuracy:
# 1.0

# %%
confusion_matrix(Ytest,log_prediction)
# Out:
# array([[7, 0, 0],
#        [0, 6, 0],
#        [0, 0, 7]], dtype=int64)

# %%
print(classification_report(Ytest,log_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       1.00      1.00      1.00         6
#            2       1.00      1.00      1.00         7
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20

# %%
from sklearn.tree import DecisionTreeClassifier

Dtc = DecisionTreeClassifier(criterion="entropy",max_depth=5)
Dtc.fit(Xtrain,Ytrain)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
dtc_prediction = Dtc.predict(Xtest)

# %%
print("Decision Tree Model Prediction: ")
accuracy_score(Ytest,dtc_prediction)
# Out:
# Decision Tree Model Prediction:
# 0.95

# %%
confusion_matrix(Ytest,dtc_prediction)
# Out:
# array([[7, 0, 0],
#        [0, 5, 1],
#        [0, 0, 7]], dtype=int64)

# %%
print(classification_report(Ytest,dtc_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       1.00      0.83      0.91         6
#            2       0.88      1.00      0.93         7
#
#     accuracy                           0.95        20
#    macro avg       0.96      0.94      0.95        20
# weighted avg       0.96      0.95      0.95        20

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3,algorithm="auto")

# %%
knn.fit(Xtrain,Ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn_prediction= knn.predict(Xtest)
knn_prediction
# Out:
# array([2, 0, 0, 2, 2, 0, 1, 1, 0, 2, 1, 2, 1, 0, 0, 1, 2, 1, 0, 1],
#       dtype=int64)

# %%
print("KNN Model Accuracy: ")
accuracy_score(Ytest,knn_prediction)
# Out:
# KNN Model Accuracy:
# 0.95

# %%
confusion_matrix(Ytest,knn_prediction)
# Out:
# array([[7, 0, 0],
#        [0, 6, 0],
#        [0, 1, 6]], dtype=int64)

# %%
print(classification_report(Ytest,knn_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       0.86      1.00      0.92         6
#            2       1.00      0.86      0.92         7
#
#     accuracy                           0.95        20
#    macro avg       0.95      0.95      0.95        20
# weighted avg       0.96      0.95      0.95        20

# %% [markdown]
# #### Logistic Regression Accuracy: 0.95 / 1.0 (95%)

# %% [markdown]
# #### Decision Tree Accuracy: 0.95 / 1.0 (95%)

# %% [markdown]
# #### KNN Accuracy: 1.0 / 1.0 (100%)
